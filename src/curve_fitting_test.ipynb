# %%
# import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import matplotlib.colors as mcolors

# %%
# reading the test data
data = pd.read_csv("/work/verbal_fluency/data_phonetic/annotation_merged_fixed.csv", sep=";", encoding="latin-1")

# %%
# defining the curve function
def func(x, c, m):
    return c * (1 - np.exp(-m * x))

# %%
# extracting unique filenames - these will be used to create subsets
subset_list = data["Filename"].unique()

# %%
subset_list
# Out:
# <StringArray>
# ['VF-001-20170310101810.wav', 'VF-001-20170310114125.wav',
#  'VF-001-20170310125920.wav', 'VF-002-20170310101923.wav',
#  'VF-002-20170310114238.wav', 'VF-002-20170310130033.wav',
#  'VF-003-20170310102036.wav', 'VF-003-20170310114351.wav',
#  'VF-003-20170310130146.wav', 'VF-001-20170316103702.wav',
#  'VF-001-20170316120337.wav', 'VF-001-20170316133043.wav',
#  'VF-002-20170316103815.wav', 'VF-002-20170316120450.wav',
#  'VF-002-20170316133156.wav', 'VF-003-20170316103928.wav',
#  'VF-003-20170316120603.wav', 'VF-003-20170316133309.wav',
#  'VF-003-20230327122603.wav', 'VF-003-20230327111833.wav',
#  'VF-003-20230327095945.wav', 'VF-002-20230327122455.wav',
#  'VF-002-20230327111725.wav', 'VF-002-20230327095837.wav',
#  'VF-001-20230327122347.wav', 'VF-001-20230327111617.wav',
#  'VF-001-20230327095728.wav', 'VF-003-20230317130317.wav',
#  'VF-003-20230317121053.wav', 'VF-003-20230317103827.wav',
#  'VF-002-20230317130209.wav', 'VF-002-20230317120944.wav',
#  'VF-002-20230317103718.wav', 'VF-001-20230317130101.wav',
#  'VF-001-20230317120836.wav', 'VF-001-20230317103610.wav',
#  'VF-003-20220426122553.wav', 'VF-003-20220426112022.wav',
#  'VF-003-20220426101601.wav', 'VF-002-20220426122445.wav',
#  'VF-002-20220426111913.wav', 'VF-002-20220426101453.wav',
#  'VF-001-20220426122336.wav', 'VF-001-20220426111805.wav',
#  'VF-001-20220426101345.wav', 'VF-003-20220331120019.wav',
#  'VF-003-20220331105531.wav', 'VF-002-20220331115911.wav',
#  'VF-002-20220331105422.wav', 'VF-001-20220331115803.wav',
#  'VF-001-20220331105314.wav', 'VF-003-20181126121703.wav',
#  'VF-003-20181126112016.wav', 'VF-003-20181126095842.wav',
#  'VF-002-20181126121550.wav', 'VF-002-20181126111903.wav',
#  'VF-002-20181126095729.wav', 'VF-001-20181126121437.wav',
#  'VF-001-20181126111750.wav', 'VF-001-20181126095616.wav',
#  'VF-001-20170329101042.wav', 'VF-001-20170329112757.wav',
#  'VF-001-20170329124340.wav', 'VF-002-20170329101155.wav',
#  'VF-002-20170329112910.wav', 'VF-002-20170329124453.wav',
#  'VF-003-20170329101309.wav', 'VF-003-20170329113023.wav',
#  'VF-003-20170329124606.wav', 'VF-001-20170330100707.wav',
#  'VF-001-20170330112323.wav', 'VF-001-20170330123815.wav',
#  'VF-002-20170330100820.wav', 'VF-002-20170330112436.wav',
#  'VF-002-20170330123928.wav', 'VF-003-20170330100933.wav',
#  'VF-003-20170330112549.wav', 'VF-003-20170330124041.wav',
#  'VF-001-20170331100053.wav', 'VF-001-20170331111633.wav',
#  'VF-001-20170331125403.wav', 'VF-002-20170331100207.wav',
#  'VF-002-20170331111746.wav', 'VF-002-20170331125516.wav',
#  'VF-003-20170331100320.wav', 'VF-003-20170331111859.wav',
#  'VF-003-20170331125629.wav', 'VF-001-20170407100012.wav',
#  'VF-001-20170407112538.wav', 'VF-001-20170407125837.wav',
#  'VF-002-20170407100125.wav', 'VF-002-20170407112651.wav',
#  'VF-002-20170407125950.wav', 'VF-003-20170407100238.wav',
#  'VF-003-20170407112804.wav', 'VF-003-20170407130103.wav']
# Length: 96, dtype: str

# %%
temp_data_list = []
skipped_files = []

# looping through the subset list
for i in range(len(subset_list)):

    # constructing a subset with only the first task
    subset = data[data["Filename"] == subset_list[i]]

    # constructing x and y vectors
    xdata = subset['Utterance start time'].values.copy()
    ydata = np.arange(1, len(xdata) + 1)

    # fixing x = 0 issue
    xdata[xdata == 0] = 0.000001

    # fitting the curve using sci-pi
    try:
        popt, pcov = curve_fit(func, xdata, ydata, method='lm')
    except RuntimeError as e:
        print(f"Skipping {subset_list[i]}: {e}")
        skipped_files.append(subset_list[i])
        continue

    # implementing the slope difference algorithm used in Andreas Højlunds matlab script
    # first, we compute the distance in seconds between utterance timestamps
    xdiffs = np.diff(xdata)

    # then, we compute the difference between the observed utterance distance and the distance predicted by the curve
    xclus = 1/xdiffs - np.diff(func(xdata, c=popt[0], m=popt[1]))/xdiffs

    # finally, we determine cluster status
    xclusidx = xclus > 0 

    # adding 'false' to the first dot
    xclusidx = np.concatenate([[False], xclusidx])

    # creating cluster IDs
    cluster_bin = xclusidx.astype(int).copy()
    current_cluster = 0

    for t in range(len(cluster_bin) - 1):
        if cluster_bin[t+1] == 1 and cluster_bin[t] == 0:
            current_cluster += 1
            cluster_bin[t] = current_cluster
        elif cluster_bin[t] == 1:
            cluster_bin[t] = current_cluster

    # handle the last element
    if cluster_bin[-1] == 1:
        cluster_bin[-1] = current_cluster

    cluster_ID = cluster_bin

    # appending the cluster information to the time points
    subset['Cluster Status'] = xclusidx.astype(int)
    subset['Cluster ID'] = cluster_ID

    temp_data_list.append(subset)

    # plotting points on curve colored by cluster ID
    plt.figure()
    n_clusters = subset['Cluster ID'].max()

    colors_list = ['grey'] + list(plt.cm.turbo(np.linspace(0, 1, n_clusters)))
    cmap = mcolors.ListedColormap(colors_list)
    bounds = np.arange(-0.5, n_clusters + 1.5)
    norm = mcolors.BoundaryNorm(bounds, cmap.N)

    plt.plot(xdata, func(xdata, *popt), 'k--', label='fit', linewidth=0.8)
    scatter = plt.scatter(xdata, ydata, c=cluster_bin, cmap=cmap, norm=norm, s=20, zorder=5)
    plt.xlabel('Time (seconds)')
    plt.ylabel('Cumulative utterance count')
    plt.title(f'Fitting curve to utterances from file {subset_list[i]}')

    cbar = plt.colorbar(scatter, ticks=np.arange(0, n_clusters + 1))
    cbar.set_ticklabels(['no cluster'] + [f'cluster {i}' for i in range(1, n_clusters + 1)])

    plt.savefig(f'/work/verbal_fluency/curvefit/{subset_list[i]}.png')

# unpack the list into a single data frame
processed_data = pd.concat(temp_data_list, axis=0, ignore_index=True)

if skipped_files:
    print(f"\nSkipped {len(skipped_files)} file(s): {skipped_files}")
# Out:
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# Skipping VF-002-20170310101923.wav: Optimal parameters not found: Number of calls to function has reached maxfev = 600.
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in multiply
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# Skipping VF-003-20230327111833.wav: Optimal parameters not found: Number of calls to function has reached maxfev = 600.
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/2670423094.py:62: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/2670423094.py:30: RuntimeWarning: divide by zero encountered in divide
#   xclus = 1/xdiffs - np.diff(func(xdata, c=popt[0], m=popt[1]))/xdiffs
# /tmp/ipykernel_1291/2670423094.py:30: RuntimeWarning: invalid value encountered in divide
#   xclus = 1/xdiffs - np.diff(func(xdata, c=popt[0], m=popt[1]))/xdiffs
# /tmp/ipykernel_1291/2670423094.py:19: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(func, xdata, ydata, method='lm')
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/2670423094.py:19: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(func, xdata, ydata, method='lm')
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# Skipping VF-001-20220426122336.wav: Optimal parameters not found: Number of calls to function has reached maxfev = 600.
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/2670423094.py:30: RuntimeWarning: divide by zero encountered in divide
#   xclus = 1/xdiffs - np.diff(func(xdata, c=popt[0], m=popt[1]))/xdiffs
# /tmp/ipykernel_1291/2670423094.py:30: RuntimeWarning: invalid value encountered in divide
#   xclus = 1/xdiffs - np.diff(func(xdata, c=popt[0], m=popt[1]))/xdiffs
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/2670423094.py:30: RuntimeWarning: divide by zero encountered in divide
#   xclus = 1/xdiffs - np.diff(func(xdata, c=popt[0], m=popt[1]))/xdiffs
# /tmp/ipykernel_1291/2670423094.py:30: RuntimeWarning: invalid value encountered in divide
#   xclus = 1/xdiffs - np.diff(func(xdata, c=popt[0], m=popt[1]))/xdiffs
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/2670423094.py:30: RuntimeWarning: divide by zero encountered in divide
#   xclus = 1/xdiffs - np.diff(func(xdata, c=popt[0], m=popt[1]))/xdiffs
# /tmp/ipykernel_1291/2670423094.py:30: RuntimeWarning: invalid value encountered in divide
#   xclus = 1/xdiffs - np.diff(func(xdata, c=popt[0], m=popt[1]))/xdiffs
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/1254897685.py:3: RuntimeWarning: overflow encountered in exp
#   return c * (1 - np.exp(-m * x))
# /tmp/ipykernel_1291/2670423094.py:30: RuntimeWarning: divide by zero encountered in divide
#   xclus = 1/xdiffs - np.diff(func(xdata, c=popt[0], m=popt[1]))/xdiffs
# /tmp/ipykernel_1291/2670423094.py:30: RuntimeWarning: invalid value encountered in divide
#   xclus = 1/xdiffs - np.diff(func(xdata, c=popt[0], m=popt[1]))/xdiffs
# Skipped 3 file(s): ['VF-002-20170310101923.wav', 'VF-003-20230327111833.wav', 'VF-001-20220426122336.wav']

# %%
temp_data_list = []

# looping through the subset list
for i in range(len(subset_list)):

    # constructing a subset with only the first task
    subset = data[data["Filename"] == subset_list[i]]

    # constructing x and y vectors
    xdata = subset['Utterance start time'].values # a vector of utterance start time in seconds
    ydata = np.arange(1, len(xdata) + 1) # cumulative count (+1 to go from 0 to 1 indexing)

    # fitting the curve using sci-pi
    popt, pcov = curve_fit(func, xdata, ydata, method='lm') # method lm = Levenberg-Marquardt algorithm

    # implementing the slope difference algorithm used in Andreas Højlunds matlab script
    # first, we compute the distance in seconds between utterance timestamps
    xdiffs = np.diff(xdata)

    # then, we compute the difference between the observed utterance distance and the distance predicted by the curve
    xclus = 1/xdiffs - np.diff(func(xdata, c=popt[0], m=popt[1]))/xdiffs

    # finally, we determine cluster status
    xclusidx = xclus > 0 

    # adding 'false' to the first dot
    xclusidx = np.concatenate([[False], xclusidx])

    # creating cluster IDs
    cluster_bin = xclusidx.astype(int).copy()
    #cluster_bin = test
    current_cluster = 0

    for t in range(len(cluster_bin) - 1):
        if cluster_bin[t+1] == 1 and cluster_bin[t] == 0:
            current_cluster += 1
            cluster_bin[t] = current_cluster
        elif cluster_bin[t] == 1:
            cluster_bin[t] = current_cluster

    # handle the last element
    if cluster_bin[-1] == 1:
        cluster_bin[-1] = current_cluster

    cluster_ID = cluster_bin

    # appending the cluster information to the time points
    subset['Cluster Status'] = xclusidx.astype(int)
    subset['Cluster ID'] = cluster_ID

    temp_data_list.append(subset)

    # plotting points on curve colored by cluster ID
    plt.figure()
    n_clusters = subset['Cluster ID'].max()

    colors_list = ['grey'] + list(plt.cm.turbo(np.linspace(0, 1, n_clusters)))
    cmap = mcolors.ListedColormap(colors_list)
    bounds = np.arange(-0.5, n_clusters + 1.5)
    norm = mcolors.BoundaryNorm(bounds, cmap.N)

    plt.plot(xdata, func(xdata, *popt), 'k--', label='fit', linewidth=0.8)
    scatter = plt.scatter(xdata, ydata, c=cluster_bin, cmap=cmap, norm=norm, s=20, zorder=5)
    plt.xlabel('Time (seconds)')
    plt.ylabel('Cumulative utterance count')
    plt.title(f'Fitting curve to utterances from file {subset_list[i]}')

    cbar = plt.colorbar(scatter, ticks=np.arange(0, n_clusters + 1))
    cbar.set_ticklabels(['no cluster'] + [f'cluster {i}' for i in range(1, n_clusters + 1)])

# unpack the list into a single data frame
processed_data = pd.concat(temp_data_list, axis=0, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[16], line 14
#      10     xdata = subset['Utterance start time'].values # a vector of utterance start time in seconds
#      11     ydata = np.arange(1, len(xdata) + 1) # cumulative count (+1 to go from 0 to 1 indexing)
#      12
#      13     # fitting the curve using sci-pi
# ---> 14     popt, pcov = curve_fit(func, xdata, ydata, method='dogbox') # method lm = Levenberg-Marquardt algorithm
#      15
#      16     # implementing the slope difference algorithm used in Andreas Højlunds matlab script
#      17     # first, we compute the distance in seconds between utterance timestamps
#
# File /work/verbal_fluency/.venv/lib/python3.12/site-packages/scipy/optimize/_minpack_py.py:1036, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#    1032 res = least_squares(func, p0, jac=jac, bounds=bounds, method=method,
#    1033                     **kwargs)
#    1035 if not res.success:
# -> 1036     raise RuntimeError("Optimal parameters not found: " + res.message)
#    1038 infodict = dict(nfev=res.nfev, fvec=res.fun)
#    1039 ier = res.status
#
# RuntimeError: Optimal parameters not found: The maximum number of function evaluations is exceeded.

# %%
subset['Cluster ID'].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /work/verbal_fluency/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'Cluster ID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 subset['Cluster ID'].max()
#
# File /work/verbal_fluency/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File /work/verbal_fluency/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'Cluster ID'

# %%
# plotting points on curve colored by cluster ID
n_clusters = cluster_bin.max()

colors_list = ['grey'] + list(plt.cm.turbo(np.linspace(0, 1, n_clusters)))
cmap = mcolors.ListedColormap(colors_list)
bounds = np.arange(-0.5, n_clusters + 1.5)
norm = mcolors.BoundaryNorm(bounds, cmap.N)

plt.plot(xdata, func(xdata, *popt), 'k--', label='fit', linewidth=0.8)
scatter = plt.scatter(xdata, ydata, c=cluster_bin, cmap=cmap, norm=norm, s=20, zorder=5)
plt.xlabel('Time (seconds)')
plt.ylabel('Cumulative utterance count')
plt.title("Fitting curve to utterances from a single VFT")

cbar = plt.colorbar(scatter, ticks=np.arange(0, n_clusters + 1))
cbar.set_ticklabels(['no cluster'] + [f'cluster {i}' for i in range(1, n_clusters + 1)])

# %%
# printing the output
subset
# Out:
#         ID             Filename  Utterance start time Estimated Lexical Match  \
# 21  VF-002  -20170208100223.wav                     1                 arbejde
# 22  VF-002  -20170208100223.wav                     2               allehånde
# 23  VF-002  -20170208100223.wav                     5                   angst
# 24  VF-002  -20170208100223.wav                     8           angel-saksisk
# 25  VF-002  -20170208100223.wav                    11              anderledes
# 26  VF-002  -20170208100223.wav                    13                      an
# 27  VF-002  -20170208100223.wav                    16                    alle
# 28  VF-002  -20170208100223.wav                    21                    arig
# 29  VF-002  -20170208100223.wav                    27                     ask
# 30  VF-002  -20170208100223.wav                    29                     asp
# 31  VF-002  -20170208100223.wav                    32                    atrå
# 32  VF-002  -20170208100223.wav                    37              assimilere
# 33  VF-002  -20170208100223.wav                    39             association
# 34  VF-002  -20170208100223.wav                    46                   artig
# 35  VF-002  -20170208100223.wav                    58                  ansigt
#
#     Certainty (1- fully uncertain, 3 fully certain) Target Letter  \
# 21                                                3             a
# 22                                                3             a
# 23                                                3             a
# 24                                                1             a
# 25                                                3             a
# 26                                                1             a
# 27                                                3             a
# 28                                                3             a
# 29                                                3             a
# 30                                                3             a
# 31                                                2             a
# 32                                                3             a
# 33                                                3             a
# 34                                                3             a
# 35                                                3             a
#
#    Audio Quality Comment  Cluster ID  Cluster Status
# 21                  high           1               0
# 22                  high           1               1
# 23                  high           0               0
# 24                  high           0               0
# 25                  high           2               0
# 26                  high           2               1
# 27                  high           0               0
# 28                  high           0               0
# 29                  high           3               0
# 30                  high           3               1
# 31                  high           3               1
# 32                  high           4               0
# 33                  high           4               1
# 34                  high           0               0
# 35                  high           0               0

# %%
# old plot
plt.plot(xdata, func(xdata, c=popt[0], m=popt[1]), 'g--')
plt.plot(xdata, ydata, 'bo', markersize=2, label='data')
plt.xlabel('Time (seconds)')
plt.ylabel('Cumulative utterance count')
plt.title("Fitting curve to utterances from a single VFT")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 # old plot
# ----> 2 plt.plot(xdata, func(xdata, c=popt[0], m=popt[1]), 'g--')
#       3 plt.plot(xdata, ydata, 'bo', markersize=2, label='data')
#       4 plt.xlabel('Time (seconds)')
#       5 plt.ylabel('Cumulative utterance count')
#
# NameError: name 'xdata' is not defined
